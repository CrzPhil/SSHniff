# %%
import json
import matplotlib.pyplot as plt
import os
from collections import defaultdict, OrderedDict
import random
import numpy as np
from scipy.interpolate import make_interp_spline

# %%
def get_raw_data(personalised=False):
    """
    Read .json files and append data to a dict with a key of sessions
    """
    data = {'sessions': []}
    if personalised:
        datadir = "./personalised_data/"
    else:
        datadir = "./data/"

    files = [fname for fname in os.listdir(datadir) if fname.endswith('.json')]
    
    for file in files:
        with open(f"{datadir}{file}", "r") as f:
            js = json.load(f)
            data['sessions'].extend(js['sessions'])
    
    return data

# %%
def what_commands(fname):
    """
    Return which commands were prompted in a given file (session)
    """
    with open (fname, "r") as f:
        js = json.load(f)
        commands = [entry['command'] for entry in js['sessions']]
    return commands

# %%
def organize_by_command(data):
    """
    Return a dict where key->command, value->list of list of keystrokes
    """
    commands = defaultdict(list)
    for session in data['sessions']:
        command = session['command']
        keystrokes = session['keystrokes']
        if len(keystrokes) == 0 or len(keystrokes) < len(command):
               continue
        commands[command].append(keystrokes)
    return commands

# %%
def zero_first(data):
    """
    Set latency of the first keystroke to zero.
    """
    for cmd in data.keys():
        for session in data[cmd]:
            session[0]['latency'] = 0
    return data

# %%
def get_prepared_data(personalised=False):
    """
    Return ordered, zeroed, data dictionary.
    """
    data = get_raw_data(personalised)
    organised = organize_by_command(data)
    zeroed = zero_first(organised)
    return zeroed

# %%
cmds = get_prepared_data(True)

# %%
def combine_common_tokens(dataset):
    """
    Certain keywords are reused in the dataset. We can combine them for increased coverage.
    i.e. sudo, install, apt, service, etc.
    """
    # We could make this selection automatic via a hashmap, but the idea is that
    # only certain keywords play a big enough role- especially for sudo, which will be an optional
    # prefix for commands to be considered.
    # If we went for all words, then we might as well draw the line at keypair latencies, which is not ideal.
    common_tokens = set(["sudo", "install", "service", "pacman", "systemctl"])
    aggregated_data = defaultdict(list)

    for command, sessions in dataset.items():
        splices = command.split()
        indices = [0]
        
        # Accumulate indices positions
        for i in range(1, len(splices)):
            indices.append(indices[-1] + len(splices[i-1]) + 1)  # Account for spaces

        for i, word in enumerate(splices):
            if word in common_tokens:
                start_idx = indices[i]
                end_idx = start_idx + len(word)  # Not including the space after the word

                # Extract the keystrokes corresponding to the word
                keystrokes = [session[start_idx:end_idx] for session in sessions]
                
                # Optionally nullify the first latency in each session to normalize start time
                for keystroke in keystrokes:
                    if keystroke:  # Ensure it's not an empty list
                        keystroke[0]['latency'] = 0

                aggregated_data[word].extend(keystrokes)

        # Add the full command data
        aggregated_data[command].extend(sessions)

    return aggregated_data

# %%
combine_common_tokens(handle_backspaces(get_prepared_data()))
# Out:
# defaultdict(list,
#             {'pwd': [[{'key': 'p', 'latency': 0},
#                {'key': 'w', 'latency': 104},
#                {'key': 'd', 'latency': 61},
#                {'key': 'Return', 'latency': 87}],
#               [{'key': 'p', 'latency': 0},
#                {'key': 'w', 'latency': 87},
#                {'key': 'd', 'latency': 147},
#                {'key': 'Return', 'latency': 107}],
#               [{'key': 'p', 'latency': 0},
#                {'key': 'w', 'latency': 38},
#                {'key': 'd', 'latency': 93},
#                {'key': 'Return', 'latency': 54}],
#               [{'key': 'p', 'latency': 0},
#                {'key': 'w', 'latency': 75},
#                {'key': 'd', 'latency': 148},
#                {'key': 'Return', 'latency': 139}]],
#              'sudo': [[{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 94},
#                {'key': 'd', 'latency': 113},
#                {'key': 'o', 'latency': 83}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 109},
#                {'key': 'd', 'latency': 145},
#                {'key': 'o', 'latency': 111}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 289},
#                {'key': 'd', 'latency': 393},
#                {'key': 'o', 'latency': 125}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 115},
#                {'key': 'd', 'latency': 138},
#                {'key': 'o', 'latency': 339}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 82},
#                {'key': 'd', 'latency': 245},
#                {'key': 'o', 'latency': 0}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 85},
#                {'key': 'd', 'latency': 89},
#                {'key': 'o', 'latency': 116}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 217},
#                {'key': 'd', 'latency': 141},
#                {'key': 'o', 'latency': 73}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 57},
#                {'key': 'd', 'latency': 125},
#                {'key': 'o', 'latency': 83}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 81},
#                {'key': 'd', 'latency': 116},
#                {'key': 'o', 'latency': 189}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 100},
#                {'key': 'd', 'latency': 108},
#                {'key': 'o', 'latency': 81}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 88},
#                {'key': 'd', 'latency': 130},
#                {'key': 'o', 'latency': 80}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 74},
#                {'key': 'd', 'latency': 124},
#                {'key': 'o', 'latency': 58}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 87},
#                {'key': 'd', 'latency': 127},
#                {'key': 'o', 'latency': 212}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 135},
#                {'key': 'd', 'latency': 144},
#                {'key': 'o', 'latency': 225}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 132},
#                {'key': 'd', 'latency': 120},
#                {'key': 'o', 'latency': 174}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 82},
#                {'key': 'd', 'latency': 121},
#                {'key': 'o', 'latency': 208}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 77},
#                {'key': 'd', 'latency': 124},
#                {'key': 'o', 'latency': 91}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 126},
#                {'key': 'd', 'latency': 161},
#                {'key': 'o', 'latency': 103}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 70},
#                {'key': 'd', 'latency': 107},
#                {'key': 'o', 'latency': 76}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 98},
#                {'key': 'd', 'latency': 94},
#                {'key': 'o', 'latency': 102}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 88},
#                {'key': 'd', 'latency': 470},
#                {'key': 'o', 'latency': 61}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 79},
#                {'key': 'd', 'latency': 116},
#                {'key': 'o', 'latency': 96}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 87},
#                {'key': 'd', 'latency': 145},
#                {'key': 'o', 'latency': 154}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 261},
#                {'key': 'd', 'latency': 0},
#                {'key': 'o', 'latency': 38}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 83},
#                {'key': 'd', 'latency': 128},
#                {'key': 'o', 'latency': 82}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 63},
#                {'key': 'd', 'latency': 127},
#                {'key': 'o', 'latency': 56}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 103},
#                {'key': 'd', 'latency': 86},
#                {'key': 'o', 'latency': 83}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 216},
#                {'key': 'd', 'latency': 126},
#                {'key': 'o', 'latency': 127}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 71},
#                {'key': 'd', 'latency': 131},
#                {'key': 'o', 'latency': 84}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 92},
#                {'key': 'd', 'latency': 118},
#                {'key': 'o', 'latency': 89}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 102},
#                {'key': 'd', 'latency': 103},
#                {'key': 'o', 'latency': 92}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 89},
#                {'key': 'd', 'latency': 120},
#                {'key': 'o', 'latency': 99}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 67},
#                {'key': 'd', 'latency': 204},
#                {'key': 'o', 'latency': 833}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 101},
#                {'key': 'd', 'latency': 90},
#                {'key': 'o', 'latency': 102}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 71},
#                {'key': 'd', 'latency': 105},
#                {'key': 'o', 'latency': 196}]],
#              'sudo command': [[{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 94},
#                {'key': 'd', 'latency': 113},
#                {'key': 'o', 'latency': 83},
#                {'key': ' ', 'latency': 101},
#                {'key': 'c', 'latency': 123},
#                {'key': 'o', 'latency': 41},
#                {'key': 'm', 'latency': 153},
#                {'key': 'm', 'latency': 117},
#                {'key': 'a', 'latency': 100},
#                {'key': 'n', 'latency': 83},
#                {'key': 'd', 'latency': 88},
#                {'key': 'Return', 'latency': 53}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 109},
#                {'key': 'd', 'latency': 145},
#                {'key': 'o', 'latency': 111},
#                {'key': ' ', 'latency': 81},
#                {'key': 'c', 'latency': 147},
#                {'key': 'o', 'latency': 48},
#                {'key': 'm', 'latency': 169},
#                {'key': 'm', 'latency': 127},
#                {'key': 'a', 'latency': 55},
#                {'key': 'n', 'latency': 92},
#                {'key': 'd', 'latency': 82},
#                {'key': 'Return', 'latency': 120}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 289},
#                {'key': 'd', 'latency': 393},
#                {'key': 'o', 'latency': 125},
#                {'key': ' ', 'latency': 108},
#                {'key': 'c', 'latency': 63},
#                {'key': 'o', 'latency': 132},
#                {'key': 'm', 'latency': 208},
#                {'key': 'm', 'latency': 152},
#                {'key': 'a', 'latency': 112},
#                {'key': 'n', 'latency': 141},
#                {'key': 'd', 'latency': 75},
#                {'key': 'Return', 'latency': 122}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 115},
#                {'key': 'd', 'latency': 138},
#                {'key': 'o', 'latency': 339},
#                {'key': ' ', 'latency': 287},
#                {'key': 'c', 'latency': 208},
#                {'key': 'o', 'latency': 73},
#                {'key': 'm', 'latency': 84},
#                {'key': 'm', 'latency': 119},
#                {'key': 'a', 'latency': 205},
#                {'key': 'n', 'latency': 0},
#                {'key': 'd', 'latency': 61},
#                {'key': 'Return', 'latency': 75}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'u', 'latency': 82},
#                {'key': 'd', 'latency': 245},
#                {'key': 'o', 'latency': 0},
#                {'key': ' ', 'latency': 45},
#                {'key': 'c', 'latency': 147},
#                {'key': 'o', 'latency': 42},
#                {'key': 'm', 'latency': 184},
#                {'key': 'm', 'latency': 127},
#                {'key': 'a', 'latency': 47},
#                {'key': 'n', 'latency': 135},
#                {'key': 'd', 'latency': 81},
#                {'key': 'Return', 'latency': 91}]],
#              'cat file': [[{'key': 'c', 'latency': 0},
#                {'key': 'a', 'latency': 132},
#                {'key': 't', 'latency': 96},
#                {'key': ' ', 'latency': 81},
#                {'key': 'f', 'latency': 102},
#                {'key': 'i', 'latency': 43},
#                {'key': 'l', 'latency': 158},
#                {'key': 'e', 'latency': 25},
#                {'key': 'Return', 'latency': 105}],
#               [{'key': 'c', 'latency': 0},
#                {'key': 'a', 'latency': 70},
#                {'key': 't', 'latency': 141},
#                {'key': ' ', 'latency': 64},
#                {'key': 'f', 'latency': 116},
#                {'key': 'i', 'latency': 22},
#                {'key': 'l', 'latency': 171},
#                {'key': 'e', 'latency': 84},
#                {'key': 'Return', 'latency': 86}],
#               [{'key': 'c', 'latency': 0},
#                {'key': 'a', 'latency': 180},
#                {'key': 't', 'latency': 160},
#                {'key': ' ', 'latency': 109},
#                {'key': 'f', 'latency': 90},
#                {'key': 'i', 'latency': 107},
#                {'key': 'l', 'latency': 125},
#                {'key': 'e', 'latency': 108},
#                {'key': 'Return', 'latency': 88}],
#               [{'key': 'c', 'latency': 0},
#                {'key': 'a', 'latency': 74},
#                {'key': 't', 'latency': 162},
#                {'key': ' ', 'latency': 82},
#                {'key': 'f', 'latency': 99},
#                {'key': 'i', 'latency': 33},
#                {'key': 'l', 'latency': 150},
#                {'key': 'e', 'latency': 117},
#                {'key': 'Return', 'latency': 116}],
#               [{'key': 'c', 'latency': 0},
#                {'key': 'a', 'latency': 190},
#                {'key': 't', 'latency': 292},
#                {'key': ' ', 'latency': 136},
#                {'key': 'f', 'latency': 149},
#                {'key': 'i', 'latency': 126},
#                {'key': 'l', 'latency': 201},
#                {'key': 'e', 'latency': 127},
#                {'key': 'Return', 'latency': 190}]],
#              'exit': [[{'key': 'e', 'latency': 0},
#                {'key': 'x', 'latency': 146},
#                {'key': 'i', 'latency': 82},
#                {'key': 't', 'latency': 105},
#                {'key': 'Return', 'latency': 56}],
#               [{'key': 'e', 'latency': 0},
#                {'key': 'x', 'latency': 148},
#                {'key': 'i', 'latency': 61},
#                {'key': 't', 'latency': 130},
#                {'key': 'Return', 'latency': 39}],
#               [{'key': 'e', 'latency': 0},
#                {'key': 'x', 'latency': 181},
#                {'key': 'i', 'latency': 79},
#                {'key': 't', 'latency': 127},
#                {'key': 'Return', 'latency': 94}]],
#              'whoami': [[{'key': 'w', 'latency': 0},
#                {'key': 'h', 'latency': 100},
#                {'key': 'o', 'latency': 149},
#                {'key': 'a', 'latency': 118},
#                {'key': 'm', 'latency': 84},
#                {'key': 'i', 'latency': 148},
#                {'key': 'Return', 'latency': 102}],
#               [{'key': 'w', 'latency': 0},
#                {'key': 'h', 'latency': 171},
#                {'key': 'o', 'latency': 83},
#                {'key': 'a', 'latency': 103},
#                {'key': 'm', 'latency': 82},
#                {'key': 'i', 'latency': 225},
#                {'key': 'Return', 'latency': 98}],
#               [{'key': 'w', 'latency': 0},
#                {'key': 'h', 'latency': 181},
#                {'key': 'o', 'latency': 108},
#                {'key': 'a', 'latency': 80},
#                {'key': 'm', 'latency': 90},
#                {'key': 'i', 'latency': 170},
#                {'key': 'Return', 'latency': 114}],
#               [{'key': 'w', 'latency': 0},
#                {'key': 'h', 'latency': 34},
#                {'key': 'o', 'latency': 93},
#                {'key': 'a', 'latency': 146},
#                {'key': 'm', 'latency': 20},
#                {'key': 'i', 'latency': 132},
#                {'key': 'Return', 'latency': 281}],
#               [{'key': 'w', 'latency': 0},
#                {'key': 'h', 'latency': 170},
#                {'key': 'o', 'latency': 49},
#                {'key': 'a', 'latency': 118},
#                {'key': 'm', 'latency': 70},
#                {'key': 'i', 'latency': 150},
#                {'key': 'Return', 'latency': 70}],
#               [{'key': 'w', 'latency': 0},
#                {'key': 'h', 'latency': 205},
#                {'key': 'o', 'latency': 63},
#                {'key': 'a', 'latency': 105},
#                {'key': 'm', 'latency': 100},
#                {'key': 'i', 'latency': 146},
#                {'key': 'Return', 'latency': 124}]],
#              'service': [[{'key': 's', 'latency': 0},
#                {'key': 'e', 'latency': 164},
#                {'key': 'r', 'latency': 61},
#                {'key': 'v', 'latency': 165},
#                {'key': 'i', 'latency': 85},
#                {'key': 'c', 'latency': 128},
#                {'key': 'e', 'latency': 57}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'e', 'latency': 149},
#                {'key': 'r', 'latency': 44},
#                {'key': 'v', 'latency': 256},
#                {'key': 'i', 'latency': 1},
#                {'key': 'c', 'latency': 64},
#                {'key': 'e', 'latency': 43}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'e', 'latency': 126},
#                {'key': 'r', 'latency': 142},
#                {'key': 'v', 'latency': 216},
#                {'key': 'i', 'latency': 180},
#                {'key': 'c', 'latency': 125},
#                {'key': 'e', 'latency': 35}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'e', 'latency': 91},
#                {'key': 'r', 'latency': 196},
#                {'key': 'v', 'latency': 180},
#                {'key': 'i', 'latency': 108},
#                {'key': 'c', 'latency': 108},
#                {'key': 'e', 'latency': 90}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'e', 'latency': 120},
#                {'key': 'r', 'latency': 51},
#                {'key': 'v', 'latency': 210},
#                {'key': 'i', 'latency': 83},
#                {'key': 'c', 'latency': 112},
#                {'key': 'e', 'latency': 57}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'e', 'latency': 147},
#                {'key': 'r', 'latency': 42},
#                {'key': 'v', 'latency': 187},
#                {'key': 'i', 'latency': 107},
#                {'key': 'c', 'latency': 42},
#                {'key': 'e', 'latency': 62}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'e', 'latency': 127},
#                {'key': 'r', 'latency': 219},
#                {'key': 'v', 'latency': 227},
#                {'key': 'i', 'latency': 130},
#                {'key': 'c', 'latency': 162},
#                {'key': 'e', 'latency': 62}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'e', 'latency': 156},
#                {'key': 'r', 'latency': 37},
#                {'key': 'v', 'latency': 221},
#                {'key': 'i', 'latency': 179},
#                {'key': 'c', 'latency': 81},
#                {'key': 'e', 'latency': 85}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'e', 'latency': 207},
#                {'key': 'r', 'latency': 96},
#                {'key': 'v', 'latency': 196},
#                {'key': 'i', 'latency': 514},
#                {'key': 'c', 'latency': 199},
#                {'key': 'e', 'latency': 159}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'e', 'latency': 45},
#                {'key': 'r', 'latency': 148},
#                {'key': 'v', 'latency': 304},
#                {'key': 'i', 'latency': 0},
#                {'key': 'c', 'latency': 81},
#                {'key': 'e', 'latency': 90}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'e', 'latency': 127},
#                {'key': 'r', 'latency': 165},
#                {'key': 'v', 'latency': 215},
#                {'key': 'i', 'latency': 141},
#                {'key': 'c', 'latency': 74},
#                {'key': 'e', 'latency': 91}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'e', 'latency': 153},
#                {'key': 'r', 'latency': 57},
#                {'key': 'v', 'latency': 161},
#                {'key': 'i', 'latency': 162},
#                {'key': 'c', 'latency': 39},
#                {'key': 'e', 'latency': 77}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'e', 'latency': 39},
#                {'key': 'r', 'latency': 62},
#                {'key': 'v', 'latency': 206},
#                {'key': 'i', 'latency': 99},
#                {'key': 'c', 'latency': 99},
#                {'key': 'e', 'latency': 44}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'e', 'latency': 95},
#                {'key': 'r', 'latency': 172},
#                {'key': 'v', 'latency': 266},
#                {'key': 'i', 'latency': 119},
#                {'key': 'c', 'latency': 113},
#                {'key': 'e', 'latency': 84}]],
#              'systemctl status service': [[{'key': 's', 'latency': 0},
#                {'key': 'y', 'latency': 245},
#                {'key': 's', 'latency': 147},
#                {'key': 't', 'latency': 135},
#                {'key': 'e', 'latency': 81},
#                {'key': 'm', 'latency': 192},
#                {'key': 'c', 'latency': 162},
#                {'key': 't', 'latency': 187},
#                {'key': 'l', 'latency': 121},
#                {'key': ' ', 'latency': 106},
#                {'key': 's', 'latency': 105},
#                {'key': 't', 'latency': 95},
#                {'key': 'a', 'latency': 85},
#                {'key': 't', 'latency': 75},
#                {'key': 'u', 'latency': 102},
#                {'key': 's', 'latency': 123},
#                {'key': ' ', 'latency': 103},
#                {'key': 's', 'latency': 0},
#                {'key': 'e', 'latency': 164},
#                {'key': 'r', 'latency': 61},
#                {'key': 'v', 'latency': 165},
#                {'key': 'i', 'latency': 85},
#                {'key': 'c', 'latency': 128},
#                {'key': 'e', 'latency': 57},
#                {'key': 'Return', 'latency': 110}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'y', 'latency': 434},
#                {'key': 's', 'latency': 60},
#                {'key': 't', 'latency': 98},
#                {'key': 'e', 'latency': 41},
#                {'key': 'm', 'latency': 599},
#                {'key': 'c', 'latency': 185},
#                {'key': 't', 'latency': 206},
#                {'key': 'l', 'latency': 67},
#                {'key': ' ', 'latency': 43},
#                {'key': 's', 'latency': 125},
#                {'key': 't', 'latency': 148},
#                {'key': 'a', 'latency': 80},
#                {'key': 't', 'latency': 112},
#                {'key': 'u', 'latency': 209},
#                {'key': 's', 'latency': 78},
#                {'key': ' ', 'latency': 52},
#                {'key': 's', 'latency': 0},
#                {'key': 'e', 'latency': 149},
#                {'key': 'r', 'latency': 44},
#                {'key': 'v', 'latency': 256},
#                {'key': 'i', 'latency': 1},
#                {'key': 'c', 'latency': 64},
#                {'key': 'e', 'latency': 43},
#                {'key': 'Return', 'latency': 95}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'y', 'latency': 289},
#                {'key': 's', 'latency': 195},
#                {'key': 't', 'latency': 271},
#                {'key': 'e', 'latency': 53},
#                {'key': 'm', 'latency': 178},
#                {'key': 'c', 'latency': 201},
#                {'key': 't', 'latency': 229},
#                {'key': 'l', 'latency': 125},
#                {'key': ' ', 'latency': 109},
#                {'key': 's', 'latency': 142},
#                {'key': 't', 'latency': 291},
#                {'key': 'a', 'latency': 214},
#                {'key': 't', 'latency': 143},
#                {'key': 'u', 'latency': 162},
#                {'key': 's', 'latency': 108},
#                {'key': ' ', 'latency': 108},
#                {'key': 's', 'latency': 0},
#                {'key': 'e', 'latency': 126},
#                {'key': 'r', 'latency': 142},
#                {'key': 'v', 'latency': 216},
#                {'key': 'i', 'latency': 180},
#                {'key': 'c', 'latency': 125},
#                {'key': 'e', 'latency': 35},
#                {'key': 'Return', 'latency': 193}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'y', 'latency': 251},
#                {'key': 's', 'latency': 90},
#                {'key': 't', 'latency': 198},
#                {'key': 'e', 'latency': 35},
#                {'key': 'm', 'latency': 250},
#                {'key': 'c', 'latency': 288},
#                {'key': 't', 'latency': 337},
#                {'key': 'l', 'latency': 118},
#                {'key': ' ', 'latency': 137},
#                {'key': 's', 'latency': 359},
#                {'key': 't', 'latency': 197},
#                {'key': 'a', 'latency': 144},
#                {'key': 't', 'latency': 233},
#                {'key': 'u', 'latency': 180},
#                {'key': 's', 'latency': 108},
#                {'key': ' ', 'latency': 125},
#                {'key': 's', 'latency': 0},
#                {'key': 'e', 'latency': 91},
#                {'key': 'r', 'latency': 196},
#                {'key': 'v', 'latency': 180},
#                {'key': 'i', 'latency': 108},
#                {'key': 'c', 'latency': 108},
#                {'key': 'e', 'latency': 90},
#                {'key': 'Return', 'latency': 179}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'y', 'latency': 172},
#                {'key': 's', 'latency': 155},
#                {'key': 't', 'latency': 113},
#                {'key': 'e', 'latency': 98},
#                {'key': 'm', 'latency': 212},
#                {'key': 'c', 'latency': 139},
#                {'key': 't', 'latency': 193},
#                {'key': 'l', 'latency': 95},
#                {'key': ' ', 'latency': 240},
#                {'key': 's', 'latency': 47},
#                {'key': 't', 'latency': 134},
#                {'key': 'a', 'latency': 77},
#                {'key': 't', 'latency': 102},
#                {'key': 'u', 'latency': 149},
#                {'key': 's', 'latency': 132},
#                {'key': ' ', 'latency': 80},
#                {'key': 's', 'latency': 0},
#                {'key': 'e', 'latency': 120},
#                {'key': 'r', 'latency': 51},
#                {'key': 'v', 'latency': 210},
#                {'key': 'i', 'latency': 83},
#                {'key': 'c', 'latency': 112},
#                {'key': 'e', 'latency': 57},
#                {'key': 'Return', 'latency': 112}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'y', 'latency': 121},
#                {'key': 's', 'latency': 126},
#                {'key': 't', 'latency': 146},
#                {'key': 'e', 'latency': 63},
#                {'key': 'm', 'latency': 190},
#                {'key': 'c', 'latency': 113},
#                {'key': 't', 'latency': 207},
#                {'key': 'l', 'latency': 186},
#                {'key': ' ', 'latency': 105},
#                {'key': 's', 'latency': 107},
#                {'key': 't', 'latency': 102},
#                {'key': 'a', 'latency': 84},
#                {'key': 't', 'latency': 63},
#                {'key': 'u', 'latency': 112},
#                {'key': 's', 'latency': 118},
#                {'key': ' ', 'latency': 107},
#                {'key': 's', 'latency': 0},
#                {'key': 'e', 'latency': 147},
#                {'key': 'r', 'latency': 42},
#                {'key': 'v', 'latency': 187},
#                {'key': 'i', 'latency': 107},
#                {'key': 'c', 'latency': 42},
#                {'key': 'e', 'latency': 62},
#                {'key': 'Return', 'latency': 104}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'y', 'latency': 122},
#                {'key': 's', 'latency': 48},
#                {'key': 't', 'latency': 131},
#                {'key': 'e', 'latency': 41},
#                {'key': 'm', 'latency': 92},
#                {'key': 'c', 'latency': 106},
#                {'key': 't', 'latency': 184},
#                {'key': 'l', 'latency': 28},
#                {'key': ' ', 'latency': 63},
#                {'key': 's', 'latency': 89},
#                {'key': 't', 'latency': 125},
#                {'key': 'a', 'latency': 65},
#                {'key': 't', 'latency': 85},
#                {'key': 'u', 'latency': 89},
#                {'key': 's', 'latency': 80},
#                {'key': ' ', 'latency': 70},
#                {'key': 's', 'latency': 0},
#                {'key': 'e', 'latency': 127},
#                {'key': 'r', 'latency': 219},
#                {'key': 'v', 'latency': 227},
#                {'key': 'i', 'latency': 130},
#                {'key': 'c', 'latency': 162},
#                {'key': 'e', 'latency': 62},
#                {'key': 'Return', 'latency': 96}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'y', 'latency': 219},
#                {'key': 's', 'latency': 200},
#                {'key': 't', 'latency': 224},
#                {'key': 'e', 'latency': 123},
#                {'key': 'm', 'latency': 160},
#                {'key': 'c', 'latency': 167},
#                {'key': 't', 'latency': 209},
#                {'key': 'l', 'latency': 160},
#                {'key': ' ', 'latency': 139},
#                {'key': 's', 'latency': 118},
#                {'key': 't', 'latency': 120},
#                {'key': 'a', 'latency': 99},
#                {'key': 't', 'latency': 60},
#                {'key': 'u', 'latency': 107},
#                {'key': 's', 'latency': 112},
#                {'key': ' ', 'latency': 103},
#                {'key': 's', 'latency': 0},
#                {'key': 'e', 'latency': 156},
#                {'key': 'r', 'latency': 37},
#                {'key': 'v', 'latency': 221},
#                {'key': 'i', 'latency': 179},
#                {'key': 'c', 'latency': 81},
#                {'key': 'e', 'latency': 85},
#                {'key': 'Return', 'latency': 96}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'y', 'latency': 217},
#                {'key': 's', 'latency': 179},
#                {'key': 't', 'latency': 218},
#                {'key': 'e', 'latency': 112},
#                {'key': 'm', 'latency': 480},
#                {'key': 'c', 'latency': 963},
#                {'key': 't', 'latency': 192},
#                {'key': 'l', 'latency': 996},
#                {'key': ' ', 'latency': 679},
#                {'key': 's', 'latency': 195},
#                {'key': 't', 'latency': 195},
#                {'key': 'a', 'latency': 229},
#                {'key': 't', 'latency': 202},
#                {'key': 'u', 'latency': 183},
#                {'key': 's', 'latency': 207},
#                {'key': ' ', 'latency': 527},
#                {'key': 's', 'latency': 0},
#                {'key': 'e', 'latency': 207},
#                {'key': 'r', 'latency': 96},
#                {'key': 'v', 'latency': 196},
#                {'key': 'i', 'latency': 514},
#                {'key': 'c', 'latency': 199},
#                {'key': 'e', 'latency': 159},
#                {'key': 'Return', 'latency': 261}],
#               [{'key': 's', 'latency': 0},
#                {'key': 'y', 'latency': 275},
#                {'key': 's', 'latency': 1},
#                {'key': 't', 'latency': 144},
#                {'key': 'e', 'latency': 86},
#                {'key': 'm', 'latency': 50},
#                {'key': 'c', 'latency': 167},
#                {'key': 't', 'latency': 168},
#                {'key': 'l', 'latency': 70},
#                {'key': ' ', 'latency': 94},
#                {'key': 's', 'latency': 188},
#                {'key': 't', 'latency': 5},
#                {'key': 'a', 'latency': 111},
#                {'key': 't', 'latency': 73},
#                {'key': 'u', 'latency': 70},
#                {'key': 's', 'latency': 90},
#                {'key': ' ', 'latency': 84},
#                {'key': 's', 'latency': 0},
#                {'key': 'e', 'latency': 45},
#                {'key': 'r', 'latency': 148},
#                {'key': 'v', 'latency': 304},
#                {'key': 'i', 'latency': 0},
#                {'key': 'c', 'latency': 81},
#                {'key': 'e', 'latency': 90},
#                {'key': 'Return', 'latency': 91}]],
#              'umount /mnt': [[{'key': 'u', 'latency': 0},
#                {'key': 'm', 'latency': 186},
#                {'key': 'o', 'latency': 167},
#                {'key': 'u', 'latency': 187},
#                {'key': 'n', 'latency': 146},
#                {'key': 't', 'latency': 164},
#                {'key': ' ', 'latency': 130},
#                {'key': '/', 'latency': 85},
#                {'key': 'm', 'latency': 218},
#                {'key': 'n', 'latency': 124},
#                {'key': 't', 'latency': 107},
#                {'key': 'Return', 'latency': 80}],
#               [{'key': 'u', 'latency': 0},
#                {'key': 'm', 'latency': 209},
#                {'key': 'o', 'latency': 187},
#                {'key': 'u', 'latency': 164},
#                {'key': 'n', 'latency': 189},
#                {'key': 't', 'latency': 60},
#                {'key': ' ', 'latency': 45},
#                {'key': '/', 'latency': 145},
#                {'key': 'm', 'latency': 206},
#                {'key': 'n', 'latency': 164},
#                {'key': 't', 'latency': 81},
#                {'key': 'Return', 'latency': 138}],
#               [{'key': 'u', 'latency': 0},
#                {'key': 'm', 'latency': 216},
#                {'key': 'o', 'latency': 189},
#                {'key': 'u', 'latency': 168},
#                {'key': 'n', 'latency': 150},
#                {'key': 't', 'latency': 157},
#                {'key': ' ', 'latency': 107},
#                {'key': '/', 'latency': 225},
#                {'key': 'm', 'latency': 405},
#                {'key': 'n', 'latency': 180},
#                {'key': 't', 'latency': 74},
#                {'key': 'Return', 'latency': 142}],
#               [{'key': 'u', 'latency': 0},
#                {'key': 'm', 'latency': 180},
#                {'key': 'o', 'latency': 180},
#                {'key': 'u', 'latency': 162},
#                {'key': 'n', 'latency': 124},
#                {'key': 't', 'latency': 170},
#                {'key': ' ', 'latency': 100},
#                {'key': '/', 'latency': 270},
#                {'key': 'm', 'latency': 249},
#                {'key': 'n', 'latency': 198},
#                {'key': 't', 'latency': 143},
#                {'key': 'Return', 'latency': 108}],
#               [{'key': 'u', 'latency': 0},
#                {'key': 'm', 'latency': 171},
#                {'key': 'o', 'latency': 175},
#                {'key': 'u', 'latency': 176},
#                {'key': 'n', 'latency': 137},
#                {'key': 't', 'latency': 114},
#                {'key': ' ', 'latency': 81},
#                {'key': '/', 'latency': 93},
#                {'key': 'm', 'latency': 250},
#                {'key': 'n', 'latency': 169},
#                {'key': 't', 'latency': 77},
#                {'key': 'Return', 'latency': 81}],
#               [{'key': 'u', 'latency': 0},
#                {'key': 'm', 'latency': 179},
#                {'key': 'o', 'latency': 81},
#                {'key': 'u', 'latency': 275},
#                {'key': 'n', 'latency': 92},
#                {'key': 't', 'latency': 84},
#                {'key': ' ', 'latency': 49},
#                {'key': '/', 'latency': 73},
#                {'key': 'm', 'latency': 76},
#                {'key': 'n', 'latency': 184},
#                {'key': 't', 'latency': 88},
#                {'key': 'Return', 'latency': 71}],
#               [{'key': 'u', 'latency': 0},
#                {'key': 'm', 'latency': 186},
#                {'key': 'o', 'latency': 190},
#                {'key': 'u', 'latency': 173},
#                {'key': 'n', 'latency': 119},
#                {'key': 't', 'latency': 85},
#                {'key': ' ', 'latency': 110},
#                {'key': '/', 'latency': 308},
#                {'key': 'm', 'latency': 232},
#                {'key': 'n', 'latency': 144},
#                {'key': 't', 'latency': 115},
#                {'key': 'Return', 'latency': 77}],
#               [{'key': 'u', 'latency': 0},
#                {'key': 'm', 'latency': 207},
#                {'key': 'o', 'latency': 177},
#                {'key': 'u', 'latency': 193},
#                {'key': 'n', 'latency': 149},
#                {'key': 't', 'latency': 122},
#                {'key': ' ', 'latency': 101},
#                {'key': '/', 'latency': 63},
#                {'key': 'm', 'latency': 126},
#                {'key': 'n', 'latency': 156},
#                {'key': 't', 'latency': 75},
#                {'key': 'Return', 'latency': 57}],
#               [{'key': 'u', 'latency': 0},
#                {'key': 'm', 'latency': 196},
#                {'key': 'o', 'latency': 155},
#                {'key': 'u', 'latency': 145},
#                {'key': 'n', 'latency': 129},
#                {'key': 't', 'latency': 142},
#                {'key': ' ', 'latency': 65},
#                {'key': '/', 'latency': 85},
#                {'key': 'm', 'latency': 206},
#                {'key': 'n', 'latency': 165},
#                {'key': 't', 'latency': 102},
#                {'key': 'Return', 'latency': 109}],
#               [{'key': 'u', 'latency': 0},
#                {'key': 'm', 'latency': 200},
#                {'key': 'o', 'latency': 132},
#                {'key': 'u', 'latency': 73},
#                {'key': 'n', 'latency': 157},
#                {'key': 't', 'latency': 61},
#                {'key': ' ', 'latency': 107},
#                {'key': '/', 'latency': 107},
#                {'key': 'm', 'latency': 164},
#                {'key': 'n', 'latency': 169},
#                {'key': 't', 'latency': 79},
#                {'key': 'Return', 'latency': 116}]],
#              'uname -a': [[{'key': 'u', 'latency': 0},
#                {'key': 'n', 'latency': 167},
#                {'key': 'a', 'latency': 126},
#                {'key': 'm', 'latency': 57},
#                {'key': 'e', 'latency': 146},
#                {'key': ' ', 'latency': 108},
#                {'key': '-', 'latency': 31},
#                {'key': 'a', 'latency': 126},
#                {'key': 'Return', 'latency': 87}],
#               [{'key': 'u', 'latency': 0},
#                {'key': 'n', 'latency': 205},
#                {'key': 'a', 'latency': 57},
#                {'key': 'm', 'latency': 116},
#                {'key': 'e', 'latency': 59},
#                {'key': ' ', 'latency': 68},
#                {'key': '-', 'latency': 94},
#                {'key': 'a', 'latency': 76},
#                {'key': 'Return', 'latency': 138}],
#               [{'key': 'u', 'latency': 0},
#                {'key': 'n', 'latency': 191},
#                {'key': 'a', 'latency': 82},
#                {'key': 'm', 'latency': 86},
#                {'key': 'e', 'latency': 468},
#                {'key': ' ', 'latency': 126},
#                {'key': '-', 'latency': 127},
#                {'key': 'a', 'latency': 52},
#                {'key': 'Return', 'latency': 141}],
#               [{'key': 'u', 'latency': 0},
#                {'key': 'n', 'latency': 158},
#                {'key': 'a', 'latency': 89},
#                {'key': 'm', 'latency': 83},
#                {'key': 'e', 'latency': 92},
#                {'key': ' ', 'latency': 83},
#                {'key': '-', 'latency': 33},
#                {'key': 'a', 'latency': 136},
#                {'key': 'Return', 'latency': 38}],
#               [{'key': 'u', 'latency': 0},
#                {'key': 'n', 'latency': 200},
#                {'key': 'a', 'latency': 77},
#                {'key': 'm', 'latency': 77},
#                {'key': 'e', 'latency': 91},
#                {'key': ' ', 'latency': 13},
#                {'key': '-', 'latency': 136},
#                {'key': 'a', 'latency': 106},
#                {'key': 'Return', 'latency': 123}]],
#              'free -m': [[{'key': 'f', 'latency': 0},
#                {'key': 'r', 'latency': 171},
#                {'key': 'e', 'latency': 56},
#                {'key': 'e', 'latency': 144},
#                {'key': ' ', 'latency': 80},
#                {'key': '-', 'latency': 87},
#                {'key': 'm', 'latency': 140},
#                {'key': 'Return', 'latency': 162}],
#               [{'key': 'f', 'latency': 0},
#                {'key': 'r', 'latency': 167},
#                {'key': 'e', 'latency': 62},
#                {'key': 'e', 'latency': 149},
#                {'key': ' ', 'latency': 85},
#                {'key': '-', 'latency': 33},
#                {'key': 'm', 'latency': 326},
#                {'key': 'Return', 'latency': 131}],
#               [{'key': 'f', 'latency': 0},
#                {'key': 'r', 'latency': 53},
#                {'key': 'e', 'latency': 181},
#                {'key': 'e', 'latency': 123},
#                {'key': ' ', 'latency': 108},
#                {'key': '-', 'latency': 35},
#                {'key': 'm', 'latency': 268},
#                {'key': 'Return', 'latency': 216}],
#               [{'key': 'f', 'latency': 0},
#                {'key': 'r', 'latency': 54},
#                {'key': 'e', 'latency': 215},
#                {'key': 'e', 'latency': 90},
#                {'key': ' ', 'latency': 126},
#                {'key': '-', 'latency': 35},
#                {'key': 'm', 'latency': 215},
#                {'key': 'Return', 'latency': 162}],
#               [{'key': 'f', 'latency': 0},
#                {'key': 'r', 'latency': 158},
#                {'key': 'e', 'latency': 56},
#                {'key': 'e', 'latency': 160},
#                {'key': ' ', 'latency': 57},
#                {'key': '-', 'latency': 56},
#                {'key': 'm', 'latency': 158},
#                {'key': 'Return', 'latency': 95}],
#               [{'key': 'f', 'latency': 0},
#                {'key': 'r', 'latency': 156},
#                {'key': 'e', 'latency': 21},
#                {'key': 'e', 'latency': 170},
#                {'key': ' ', 'latency': 60},
#                {'key': '-', 'latency': 60},
#                {'key': 'm', 'latency': 127},
#                {'key': 'Return', 'latency': 116}],
#               [{'key': 'f', 'latency': 0},
#                {'key': 'r', 'latency': 165},
#                {'key': 'e', 'latency': 22},
#                {'key': 'e', 'latency': 168},
#                {'key': ' ', 'latency': 39},
#                {'key': '-', 'latency': 124},
#                {'key': 'm', 'latency': 144},
#                {'key': 'Return', 'latency': 125}],
#               [{'key': 'f', 'latency': 0},
#                {'key': 'r', 'latency': 174},
#                {'key': 'e', 'latency': 57},
#                {'key': 'e', 'latency': 120},
#                {'key': ' ', 'latency': 61},
#                {'key': '-', 'latency': 89},
#                {'key': 'm', 'latency': 137},
#                {'key': 'Return', 'latency': 111}]],
#              'htop': [[{'key': 'h', 'latency': 0},
#                {'key': 't', 'latency': 79},
#                {'key': 'o', 'latency': 85},
#                {'key': 'p', 'latency': 140},
#                {'key': 'Return', 'latency': 87}],
#               [{'key': 'h', 'latency': 0},
#                {'key': 't', 'latency': 103},
#                {'key': 'o', 'latency': 343},
#                {'key': 'p', 'latency': 178},
#                {'key': 'Return', 'latency': 253}],
#               [{'key': 'h', 'latency': 0},
#                {'key': 't', 'latency': 112},
#                {'key': 'o', 'latency': 76},
#                {'key': 'p', 'latency': 116},
#                {'key': 'Return', 'latency': 115}],
#               [{'key': 'h', 'latency': 0},
#                {'key': 't', 'latency': 89},
#                {'key': 'o', 'latency': 27},
#                {'key': 'p', 'latency': 114},
#                {'key': 'Return', 'latency': 93}],
#               [{'key': 'h', 'latency': 0},
#                {'key': 't', 'latency': 89},
#                {'key': 'o', 'latency': 64},
#                {'key': 'p', 'latency': 135},
#                {'key': 'Return', 'latency': 182}]],
#              'ss -tuln': [[{'key': 's', 'latency': 0},
#                {'key': 's', 'latency': 161},
#                {'key': ' ', 'latency': 105},
#                {'key': '-', 'latency': 347},
#                {'key': 't', 'latency': 250},
#                {'key': 'u', 'latency': 85},
#                {'key': 'l', 'latency': 205},
#                {'key': 'n', 'latency': 190},
#                {'key': 'Return', 'latency': 155}],
#               [{'key': 's', 'latency': 0},
#                {'key': 's', 'latency': 166},
#                {'key': ' ', 'latency': 84},
#                {'key': '-', 'latency': 67},
#                {'key': 't', 'latency': 135},
#                {'key': 'u', 'latency': 101},
#                {'key': 'l', 'latency': 227},
#                {'key': 'n', 'latency': 164},
#                {'key': 'Return', 'latency': 187}],
#               [{'key': 's', 'latency': 0},
#                {'key': 's', 'latency': 156},
#                {'key': ' ', 'latency': 138},
#                {'key': '-', 'latency': 50},
#                {'key': 't', 'latency': 158},
#                {'key': 'u', 'latency': 101},
#                {'key': 'l', 'latency': 168},
#                {'key': 'n', 'latency': 171},
#                {'key': 'Return', 'latency': 118}],
#               [{'key': 's', 'latency': 0},
#                {'key': 's', 'latency': 147},
#                {'key': ' ', 'latency': 63},
#                {'key': '-', 'latency': 82},
#                {'key': 't', 'latency': 127},
#                {'key': 'u', 'latency': 164},
#                {'key': 'l', 'latency': 164},
#                {'key': 'n', 'latency': 165},
#                {'key': 'Return', 'latency': 125}],
#               [{'key': 's', 'latency': 0},
#                {'key': 's', 'latency': 162},
#                {'key': ' ', 'latency': 142},
#                {'key': '-', 'latency': 86},
#                {'key': 't', 'latency': 140},
#                {'key': 'u', 'latency': 97},
#                {'key': 'l', 'latency': 178},
#                {'key': 'n', 'latency': 180},
#                {'key': 'Return', 'latency': 123}]],
#              'netstat -tuln': [[{'key': 'n', 'latency': 0},
#                {'key': 'e', 'latency': 114},
#                {'key': 't', 'latency': 50},
#                {'key': 's', 'latency': 145},
#                {'key': 't', 'latency': 125},
#                {'key': 'a', 'latency': 83},
#                {'key': 't', 'latency': 149},
#                {'key': ' ', 'latency': 103},
#                {'key': '-', 'latency': 168},
#                {'key': 't', 'latency': 672},
#                {'key': 'u', 'latency': 114},
#                {'key': 'l', 'latency': 157},
#                {'key': 'n', 'latency': 163},
#                {'key': 'Return', 'latency': 131}],
#               [{'key': 'n', 'latency': 0},
#                {'key': 'e', 'latency': 60},
#                {'key': 't', 'latency': 91},
#                {'key': 's', 'latency': 103},
#                {'key': 't', 'latency': 109},
#                {'key': 'a', 'latency': 80},
#                {'key': 't', 'latency': 108},
#                {'key': ' ', 'latency': 47},
#                {'key': '-', 'latency': 114},
#                {'key': 't', 'latency': 141},
#                {'key': 'u', 'latency': 189},
#                {'key': 'l', 'latency': 228},
#                {'key': 'n', 'latency': 62},
#                {'key': 'Return', 'latency': 134}],
#               [{'key': 'n', 'latency': 0},
#                {'key': 'e', 'latency': 86},
#                {'key': 't', 'latency': 99},
#                {'key': 's', 'latency': 141},
#                {'key': 't', 'latency': 120},
#                {'key': 'a', 'latency': 102},
#                {'key': 't', 'latency': 131},
#                {'key': ' ', 'latency': 102},
#                {'key': '-', 'latency': 197},
#                {'key': 't', 'latency': 355},
#                {'key': 'u', 'latency': 110},
#                {'key': 'l', 'latency': 183},
#                {'key': 'n', 'latency': 160},
#                {'key': 'Return', 'latency': 107}],
#               [{'key': 'n', 'latency': 0},
#                {'key': 'e', 'latency': 142},
#                {'key': 't', 'latency': 521},
#                {'key': 's', 'latency': 233},
#                {'key': 't', 'latency': 159},
#                {'key': 'a', 'latency': 185},
#                {'key': 't', 'latency': 122},
#                {'key': ' ', 'latency': 182},
#                {'key': '-', 'latency': 246},
#                {'key': 't', 'latency': 466},
#                {'key': 'u', 'latency': 215},
#                {'key': 'l', 'latency': 224},
#                {'key': 'n', 'latency': 261},
#                {'key': 'Return', 'latency': 377}],
#               [{'key': 'n', 'latency': 220},
#                {'key': 'e', 'latency': 69},
#                {'key': 't', 'latency': 232},
#                {'key': 's', 'latency': 219},
#                {'key': 't', 'latency': 218},
#                {'key': 'a', 'latency': 123},
#                {'key': 't', 'latency': 177},
#                {'key': ' ', 'latency': 148},
#                {'key': '-', 'latency': 158},
#                {'key': 't', 'latency': 1257},
#                {'key': 'u', 'latency': 34},
#                {'key': 'l', 'latency': 252},
#                {'key': 'n', 'latency': 180},
#                {'key': 'Return', 'latency': 215}],
#               [{'key': 'n', 'latency': 0},
#                {'key': 'e', 'latency': 115},
#                {'key': 't', 'latency': 63},
#                {'key': 's', 'latency': 197},
#                {'key': 't', 'latency': 56},
#                {'key': 'a', 'latency': 101},
#                {'key': 't', 'latency': 153},
#                {'key': ' ', 'latency': 56},
#                {'key': '-', 'latency': 102},
#                {'key': 't', 'latency': 186},
#                {'key': 'u', 'latency': 64},
#                {'key': 'l', 'latency': 274},
#                {'key': 'n', 'latency': 85},
#                {'key': 'Return', 'latency': 279}],
#               [{'key': 'n', 'latency': 0},
#                {'key': 'e', 'latency': 148},
#                {'key': 't', 'latency': 105},
#                {'key': 's', 'latency': 209},
#                {'key': 't', 'latency': 167},
#                {'key': 'a', 'latency': 187},
#                {'key': 't', 'latency': 149},
#                {'key': ' ', 'latency': 149},
#                {'key': '-', 'latency': 147},
#                {'key': 't', 'latency': 107},
# ...
#                {'key': 'u', 'latency': 171},
#                {'key': 'r', 'latency': 79},
#                {'key': 'l', 'latency': 85},
#                {'key': ' ', 'latency': 449},
#                {'key': 'h', 'latency': 4},
#                {'key': 't', 'latency': 105},
#                {'key': 't', 'latency': 0},
#                {'key': 'p', 'latency': 47},
#                {'key': 's', 'latency': 143},
#                {'key': ':', 'latency': 147},
#                {'key': '/', 'latency': 350},
#                {'key': '/', 'latency': 7},
#                {'key': 'e', 'latency': 0},
#                {'key': 'x', 'latency': 316},
#                {'key': 'a', 'latency': 0},
#                {'key': 'm', 'latency': 148},
#                {'key': 'p', 'latency': 165},
#                {'key': 'l', 'latency': 224},
#                {'key': 'e', 'latency': 71},
#                {'key': '.', 'latency': 83},
#                {'key': 'c', 'latency': 607},
#                {'key': 'o', 'latency': 252},
#                {'key': 'm', 'latency': 149},
#                {'key': 'Return', 'latency': 228}],
#               [{'key': 'c', 'latency': 0},
#                {'key': 'u', 'latency': 88},
#                {'key': 'r', 'latency': 128},
#                {'key': 'l', 'latency': 99},
#                {'key': ' ', 'latency': 150},
#                {'key': 'h', 'latency': 103},
#                {'key': 't', 'latency': 144},
#                {'key': 't', 'latency': 147},
#                {'key': 'p', 'latency': 62},
#                {'key': 's', 'latency': 166},
#                {'key': ':', 'latency': 105},
#                {'key': '/', 'latency': 191},
#                {'key': '/', 'latency': 108},
#                {'key': 'e', 'latency': 168},
#                {'key': 'x', 'latency': 170},
#                {'key': 'a', 'latency': 80},
#                {'key': 'm', 'latency': 91},
#                {'key': 'p', 'latency': 164},
#                {'key': 'l', 'latency': 336},
#                {'key': 'e', 'latency': 209},
#                {'key': '.', 'latency': 170},
#                {'key': 'c', 'latency': 130},
#                {'key': 'o', 'latency': 80},
#                {'key': 'm', 'latency': 154},
#                {'key': 'Return', 'latency': 82}],
#               [{'key': 'c', 'latency': 0},
#                {'key': 'u', 'latency': 83},
#                {'key': 'r', 'latency': 135},
#                {'key': 'l', 'latency': 76},
#                {'key': ' ', 'latency': 130},
#                {'key': 'h', 'latency': 101},
#                {'key': 't', 'latency': 110},
#                {'key': 't', 'latency': 163},
#                {'key': 'p', 'latency': 87},
#                {'key': 's', 'latency': 142},
#                {'key': ':', 'latency': 145},
#                {'key': '/', 'latency': 170},
#                {'key': '/', 'latency': 131},
#                {'key': 'e', 'latency': 58},
#                {'key': 'x', 'latency': 153},
#                {'key': 'a', 'latency': 97},
#                {'key': 'm', 'latency': 64},
#                {'key': 'p', 'latency': 168},
#                {'key': 'l', 'latency': 151},
#                {'key': 'e', 'latency': 106},
#                {'key': '.', 'latency': 78},
#                {'key': 'c', 'latency': 126},
#                {'key': 'o', 'latency': 104},
#                {'key': 'm', 'latency': 168},
#                {'key': 'Return', 'latency': 124}],
#               [{'key': 'c', 'latency': 0},
#                {'key': 'u', 'latency': 100},
#                {'key': 'r', 'latency': 128},
#                {'key': 'l', 'latency': 122},
#                {'key': ' ', 'latency': 112},
#                {'key': 'h', 'latency': 170},
#                {'key': 't', 'latency': 271},
#                {'key': 't', 'latency': 153},
#                {'key': 'p', 'latency': 80},
#                {'key': 's', 'latency': 151},
#                {'key': ':', 'latency': 191},
#                {'key': '/', 'latency': 209},
#                {'key': '/', 'latency': 140},
#                {'key': 'e', 'latency': 90},
#                {'key': 'x', 'latency': 193},
#                {'key': 'a', 'latency': 74},
#                {'key': 'm', 'latency': 102},
#                {'key': 'p', 'latency': 169},
#                {'key': 'l', 'latency': 152},
#                {'key': 'e', 'latency': 118},
#                {'key': '.', 'latency': 116},
#                {'key': 'c', 'latency': 115},
#                {'key': 'o', 'latency': 150},
#                {'key': 'm', 'latency': 153},
#                {'key': 'Return', 'latency': 95}],
#               [{'key': 'c', 'latency': 0},
#                {'key': 'u', 'latency': 103},
#                {'key': 'r', 'latency': 126},
#                {'key': 'l', 'latency': 103},
#                {'key': ' ', 'latency': 105},
#                {'key': 'h', 'latency': 192},
#                {'key': 't', 'latency': 147},
#                {'key': 't', 'latency': 128},
#                {'key': 'p', 'latency': 60},
#                {'key': 's', 'latency': 145},
#                {'key': ':', 'latency': 126},
#                {'key': '/', 'latency': 167},
#                {'key': '/', 'latency': 122},
#                {'key': 'e', 'latency': 130},
#                {'key': 'x', 'latency': 156},
#                {'key': 'a', 'latency': 103},
#                {'key': 'm', 'latency': 60},
#                {'key': 'p', 'latency': 167},
#                {'key': 'l', 'latency': 148},
#                {'key': 'e', 'latency': 98},
#                {'key': '.', 'latency': 152},
#                {'key': 'c', 'latency': 248},
#                {'key': 'o', 'latency': 63},
#                {'key': 'm', 'latency': 164},
#                {'key': 'Return', 'latency': 105}]],
#              'ps -aux': [[{'key': 'p', 'latency': 0},
#                {'key': 's', 'latency': 97},
#                {'key': ' ', 'latency': 105},
#                {'key': '-', 'latency': 25},
#                {'key': 'a', 'latency': 163},
#                {'key': 'u', 'latency': 95},
#                {'key': 'x', 'latency': 81},
#                {'key': 'Return', 'latency': 108}],
#               [{'key': 'p', 'latency': 0},
#                {'key': 's', 'latency': 92},
#                {'key': ' ', 'latency': 64},
#                {'key': '-', 'latency': 96},
#                {'key': 'a', 'latency': 117},
#                {'key': 'u', 'latency': 108},
#                {'key': 'x', 'latency': 230},
#                {'key': 'Return', 'latency': 71}],
#               [{'key': 'p', 'latency': 0},
#                {'key': 's', 'latency': 96},
#                {'key': ' ', 'latency': 71},
#                {'key': '-', 'latency': 104},
#                {'key': 'a', 'latency': 110},
#                {'key': 'u', 'latency': 150},
#                {'key': 'x', 'latency': 78},
#                {'key': 'Return', 'latency': 114}],
#               [{'key': 'p', 'latency': 0},
#                {'key': 's', 'latency': 179},
#                {'key': ' ', 'latency': 48},
#                {'key': '-', 'latency': 112},
#                {'key': 'a', 'latency': 117},
#                {'key': 'u', 'latency': 112},
#                {'key': 'x', 'latency': 184},
#                {'key': 'Return', 'latency': 167}],
#               [{'key': 'p', 'latency': 0},
#                {'key': 's', 'latency': 143},
#                {'key': ' ', 'latency': 156},
#                {'key': '-', 'latency': 212},
#                {'key': 'a', 'latency': 341},
#                {'key': 'u', 'latency': 227},
#                {'key': 'x', 'latency': 468},
#                {'key': 'Return', 'latency': 289}]],
#              'top': [[{'key': 't', 'latency': 0},
#                {'key': 'o', 'latency': 60},
#                {'key': 'p', 'latency': 187},
#                {'key': 'Return', 'latency': 235}],
#               [{'key': 't', 'latency': 0},
#                {'key': 'o', 'latency': 14},
#                {'key': 'p', 'latency': 66},
#                {'key': 'Return', 'latency': 102}],
#               [{'key': 't', 'latency': 0},
#                {'key': 'o', 'latency': 38},
#                {'key': 'p', 'latency': 119},
#                {'key': 'Return', 'latency': 80}],
#               [{'key': 't', 'latency': 0},
#                {'key': 'o', 'latency': 42},
#                {'key': 'p', 'latency': 113},
#                {'key': 'Return', 'latency': 123}],
#               [{'key': 't', 'latency': 0},
#                {'key': 'o', 'latency': 39},
#                {'key': 'p', 'latency': 168},
#                {'key': 'Return', 'latency': 82}],
#               [{'key': 't', 'latency': 0},
#                {'key': 'o', 'latency': 29},
#                {'key': 'p', 'latency': 230},
#                {'key': 'Return', 'latency': 45}]],
#              'chown root:root file': [[{'key': 'c', 'latency': 0},
#                {'key': 'h', 'latency': 85},
#                {'key': 'o', 'latency': 167},
#                {'key': 'w', 'latency': 117},
#                {'key': 'n', 'latency': 168},
#                {'key': ' ', 'latency': 135},
#                {'key': 'r', 'latency': 285},
#                {'key': 'o', 'latency': 85},
#                {'key': 'o', 'latency': 145},
#                {'key': 't', 'latency': 80},
#                {'key': ':', 'latency': 147},
#                {'key': 'r', 'latency': 235},
#                {'key': 'o', 'latency': 114},
#                {'key': 'o', 'latency': 162},
#                {'key': 't', 'latency': 60},
#                {'key': ' ', 'latency': 121},
#                {'key': 'f', 'latency': 125},
#                {'key': 'i', 'latency': 79},
#                {'key': 'l', 'latency': 60},
#                {'key': 'e', 'latency': 59},
#                {'key': 'Return', 'latency': 118}],
#               [{'key': 'c', 'latency': 0},
#                {'key': 'h', 'latency': 82},
#                {'key': 'o', 'latency': 207},
#                {'key': 'w', 'latency': 136},
#                {'key': 'n', 'latency': 90},
#                {'key': ' ', 'latency': 156},
#                {'key': 'r', 'latency': 115},
#                {'key': 'o', 'latency': 97},
#                {'key': 'o', 'latency': 130},
#                {'key': 't', 'latency': 97},
#                {'key': ':', 'latency': 131},
#                {'key': 'r', 'latency': 174},
#                {'key': 'o', 'latency': 99},
#                {'key': 'o', 'latency': 136},
#                {'key': 't', 'latency': 110},
#                {'key': ' ', 'latency': 347},
#                {'key': 'f', 'latency': 367},
#                {'key': 'i', 'latency': 95},
#                {'key': 'l', 'latency': 193},
#                {'key': 'e', 'latency': 86},
#                {'key': 'Return', 'latency': 130}],
#               [{'key': 'c', 'latency': 0},
#                {'key': 'h', 'latency': 64},
#                {'key': 'o', 'latency': 253},
#                {'key': 'w', 'latency': 56},
#                {'key': 'n', 'latency': 131},
#                {'key': ' ', 'latency': 88},
#                {'key': 'r', 'latency': 82},
#                {'key': 'o', 'latency': 49},
#                {'key': 'o', 'latency': 128},
#                {'key': 't', 'latency': 81},
#                {'key': ':', 'latency': 237},
#                {'key': 'r', 'latency': 204},
#                {'key': 'o', 'latency': 51},
#                {'key': 'o', 'latency': 126},
#                {'key': 't', 'latency': 79},
#                {'key': ' ', 'latency': 86},
#                {'key': 'f', 'latency': 147},
#                {'key': 'i', 'latency': 48},
#                {'key': 'l', 'latency': 170},
#                {'key': 'e', 'latency': 57},
#                {'key': 'Return', 'latency': 119}],
#               [{'key': 'c', 'latency': 0},
#                {'key': 'h', 'latency': 144},
#                {'key': 'o', 'latency': 159},
#                {'key': 'w', 'latency': 121},
#                {'key': 'n', 'latency': 105},
#                {'key': ' ', 'latency': 119},
#                {'key': 'r', 'latency': 140},
#                {'key': 'o', 'latency': 79},
#                {'key': 'o', 'latency': 143},
#                {'key': 't', 'latency': 141},
#                {'key': ':', 'latency': 143},
#                {'key': 'r', 'latency': 155},
#                {'key': 'o', 'latency': 80},
#                {'key': 'o', 'latency': 115},
#                {'key': 't', 'latency': 83},
#                {'key': ' ', 'latency': 100},
#                {'key': 'f', 'latency': 118},
#                {'key': 'i', 'latency': 42},
#                {'key': 'l', 'latency': 157},
#                {'key': 'e', 'latency': 62},
#                {'key': 'Return', 'latency': 79}]],
#              'id': [[{'key': 'i', 'latency': 0},
#                {'key': 'd', 'latency': 73},
#                {'key': 'Return', 'latency': 113}]],
#              'iostat': [[{'key': 'i', 'latency': 0},
#                {'key': 'o', 'latency': 204},
#                {'key': 's', 'latency': 173},
#                {'key': 't', 'latency': 102},
#                {'key': 'a', 'latency': 98},
#                {'key': 't', 'latency': 68},
#                {'key': 'Return', 'latency': 118}],
#               [{'key': 'i', 'latency': 0},
#                {'key': 'o', 'latency': 183},
#                {'key': 's', 'latency': 83},
#                {'key': 't', 'latency': 125},
#                {'key': 'a', 'latency': 98},
#                {'key': 't', 'latency': 130},
#                {'key': 'Return', 'latency': 125}],
#               [{'key': 'i', 'latency': 0},
#                {'key': 'o', 'latency': 187},
#                {'key': 's', 'latency': 113},
#                {'key': 't', 'latency': 137},
#                {'key': 'a', 'latency': 82},
#                {'key': 't', 'latency': 102},
#                {'key': 'Return', 'latency': 102}]],
#              'rmdir /etc/id': [[{'key': 'r', 'latency': 0},
#                {'key': 'm', 'latency': 88},
#                {'key': 'd', 'latency': 223},
#                {'key': 'i', 'latency': 90},
#                {'key': 'r', 'latency': 105},
#                {'key': ' ', 'latency': 64},
#                {'key': '/', 'latency': 93},
#                {'key': 'e', 'latency': 77},
#                {'key': 't', 'latency': 68},
#                {'key': 'c', 'latency': 188},
#                {'key': '/', 'latency': 29},
#                {'key': 'i', 'latency': 208},
#                {'key': 'd', 'latency': 57},
#                {'key': 'Return', 'latency': 139}],
#               [{'key': 'r', 'latency': 0},
#                {'key': 'm', 'latency': 179},
#                {'key': 'd', 'latency': 671},
#                {'key': 'i', 'latency': 178},
#                {'key': 'r', 'latency': 220},
#                {'key': ' ', 'latency': 685},
#                {'key': '/', 'latency': 820},
#                {'key': 'e', 'latency': 238},
#                {'key': 't', 'latency': 187},
#                {'key': 'c', 'latency': 272},
#                {'key': '/', 'latency': 305},
#                {'key': 'i', 'latency': 469},
#                {'key': 'd', 'latency': 148},
#                {'key': 'Return', 'latency': 320}],
#               [{'key': 'r', 'latency': 0},
#                {'key': 'm', 'latency': 72},
#                {'key': 'd', 'latency': 196},
#                {'key': 'i', 'latency': 111},
#                {'key': 'r', 'latency': 122},
#                {'key': ' ', 'latency': 142},
#                {'key': '/', 'latency': 101},
#                {'key': 'e', 'latency': 103},
#                {'key': 't', 'latency': 101},
#                {'key': 'c', 'latency': 147},
#                {'key': '/', 'latency': 48},
#                {'key': 'i', 'latency': 207},
#                {'key': 'd', 'latency': 80},
#                {'key': 'Return', 'latency': 92}]],
#              'cd ~': [[{'key': 'c', 'latency': 0},
#                {'key': 'd', 'latency': 270},
#                {'key': ' ', 'latency': 350},
#                {'key': '~', 'latency': 961},
#                {'key': 'Return', 'latency': 593}],
#               [{'key': 'c', 'latency': 0},
#                {'key': 'd', 'latency': 95},
#                {'key': ' ', 'latency': 163},
#                {'key': '~', 'latency': 129},
#                {'key': 'Return', 'latency': 158}],
#               [{'key': 'c', 'latency': 0},
#                {'key': 'd', 'latency': 85},
#                {'key': ' ', 'latency': 85},
#                {'key': '~', 'latency': 205},
#                {'key': 'Return', 'latency': 171}]]})

# %%
cmds = combine_common_tokens(handle_backspaces(get_prepared_data(True)))

# %%
[i for i in cmds if len(cmds[i]) >= 2]
# Out:
# ['exit',
#  'sudo',
#  'sudo su',
#  'iptables -S',
#  'sudo apt update',
#  'cat /etc/resolv.conf',
#  'cat /etc/hosts',
#  'ping -c 1 9.9.9.9',
#  'ifconfig',
#  'systemctl',
#  'systemctl start ',
#  'curl http://',
#  'uptime',
#  'systemctl stop ',
#  'mv * ../',
#  'systemctl status ',
#  'cat /etc/passwd',
#  'rm -rf /tmp/*',
#  'wget https://',
#  'systemctl restart ',
#  'id',
#  'df -hT /',
#  'tar --help',
#  'cd',
#  'tail /var/log/syslog',
#  'whoami',
#  'sudo apt upgrade ',
#  'iptables -L',
#  'touch ']

# %%
def plot_command_latencies(keystroke_sequences, command):
    plt.figure(figsize=(12, 8))
    
    for sequence in keystroke_sequences:
        latencies = [keystroke['latency'] for keystroke in sequence]
        plt.plot(latencies, marker='o', linestyle='-')

    plt.title(f'Latencies for Command: {command}')
    plt.xlabel('Keystroke Sequence Number')
    plt.ylabel('Latency (ms)')
    plt.legend([f'Session {i+1}' for i in range(len(keystroke_sequences))], loc='upper right')
    plt.grid(True)
    plt.show()

# %%
command = 'iptables -L'
plot_command_latencies(cmds[command], command)

# %%
cmds['ifconfig'][2]
# Out:
# [{'key': 'i', 'latency': 0},
#  {'key': 'd', 'latency': 250},
#  {'key': 'Backspace', 'latency': 263},
#  {'key': 'f', 'latency': 86},
#  {'key': 'c', 'latency': 135},
#  {'key': 'o', 'latency': 125},
#  {'key': 'n', 'latency': 198},
#  {'key': 'f', 'latency': 107},
#  {'key': 'i', 'latency': 108},
#  {'key': 'g', 'latency': 108},
#  {'key': 'Return', 'latency': 108}]

# %%
def handle_backspaces(keystroke_sequences):
    for command in keystroke_sequences.keys():
        for sequence in keystroke_sequences[command]:
            i = 0
            while i < len(sequence)-1:
                if sequence[i]['key'] == 'Backspace':
                    curr = sequence[i]
                    prev = sequence[i-1]
                    if i != 0:
                        sequence.remove(prev)
                        sequence.remove(curr)
                        i -= 1
                        continue
                    else:
                        sequence.remove(curr)
                        sequence[i+1]['latency'] = 0
                        continue
                i += 1
    return keystroke_sequences

# %%
cmds = handle_backspaces(cmds)

# %%
def plot_command_latencies(keystroke_sequences, command):
    plt.figure(figsize=(12, 8))
    
    for sequence_idx, sequence in enumerate(keystroke_sequences):
        normal_keys_x = []
        normal_keys_y = []
        backspace_keys_x = []
        backspace_keys_y = []
        
        for keystroke_idx, keystroke in enumerate(sequence):
            if keystroke['key'] == 'Backspace':
                backspace_keys_x.append(keystroke_idx)
                backspace_keys_y.append(keystroke['latency'])
            normal_keys_x.append(keystroke_idx)
            normal_keys_y.append(keystroke['latency'])
                
        # Plot normal keystrokes
        plt.plot(normal_keys_x, normal_keys_y, marker='o', linestyle='-', label=f'Session {sequence_idx + 1} Keystrokes', zorder=1)
        # Plot Backspace keystrokes
        plt.scatter(backspace_keys_x, backspace_keys_y, color='red', marker='x', label=f'Session {sequence_idx + 1} Backspaces', zorder=2)

    plt.title(f'Latencies for Command: {command}')
    plt.xlabel('Keystroke Sequence Number')
    plt.ylabel('Latency (ms)')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.grid(True)
    plt.show()

# %%
command = "ifconfig"
plot_command_latencies(cmds[command], command)

# %%
def plot_command_distribution(keystroke_sequences, command):
    plt.figure(figsize=(12, 8))

    total_latencies = [0] * (len(command) + 1)
    count_per_position = [0] * (len(command) + 1)

    # Plot each keystroke sequence
    for sequence in keystroke_sequences:
        normal_keys_x = []
        normal_keys_y = []
        
        for idx, keystroke in enumerate(sequence):
            normal_keys_x.append(idx)
            normal_keys_y.append(keystroke['latency'])
            if idx < len(total_latencies):
                total_latencies[idx] += keystroke['latency']
                count_per_position[idx] += 1

        plt.plot(normal_keys_x, normal_keys_y, marker='o', linestyle='-', color='blue', alpha=0.3, zorder=1)
    
    # Calculate mean latencies
    means = [total_latencies[i] / count_per_position[i] if count_per_position[i] else 0 for i in range(len(command)+1)]
    x_new = np.linspace(0, len(command), 300)  # 300 represents number of points to make between T.min and T.max

    # Smoothing the line
    spl = make_interp_spline(range(len(command)+1), means, k=3)  # BSpline object
    y_smooth = spl(x_new)

    plt.plot(x_new, y_smooth, marker='', linestyle='-', label='Mean keystroke latency', color='red', linewidth=2, zorder=2)

    plt.title(f'Mean latencies for command: "{command}"')
    plt.xlabel('Keystroke Sequence Number')
    plt.ylabel('Latency (ms)')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.grid(True)
    plt.tight_layout()  # Adjust layout to make room for the legend
    plt.show()

# %%
cmds = combine_common_tokens(handle_backspaces(get_prepared_data(True)))

# %%
command = 'exit'
plot_command_distribution(cmds[command], command)

# %%
def load_ssh_session(path, stream=0):
    """
    Load SSHniff session (JSON) output.

    By default, assume single-session, which will have stream="0".
    """
    stream = str(stream)
    
    with open(path, "r") as f:
        data = json.loads(f.read())
    # SSHniff full output
    if 'keystroke_data' in data[stream]:
        return convert_latencies(data[stream]['keystroke_data'])
    # Only keystroke data
    return convert_latencies(data[stream])

# %%
def convert_latencies(ssh_data):
    """
    Convert latencies from microseconds to milliseconds. 
    """
    for sequence in ssh_data:
        for keystroke in sequence:
            keystroke['timestamp'] = keystroke['timestamp'] / 1000
    return ssh_data

# %%
ssh_data = load_ssh_session("./sshniff_output/keystrokes.json")

# %%
ssh_data[0]
# Out:
# [{'k_type': 'Keystroke', 'timestamp': 0.0, 'response_size': None, 'seq': 2602},
#  {'k_type': 'Keystroke',
#   'timestamp': 224.186,
#   'response_size': None,
#   'seq': 2638},
#  {'k_type': 'Keystroke',
#   'timestamp': 144.008,
#   'response_size': None,
#   'seq': 2674},
#  {'k_type': 'Keystroke',
#   'timestamp': 103.813,
#   'response_size': None,
#   'seq': 2710},
#  {'k_type': 'Keystroke',
#   'timestamp': 167.979,
#   'response_size': None,
#   'seq': 2746},
#  {'k_type': 'Keystroke',
#   'timestamp': 120.27,
#   'response_size': None,
#   'seq': 2782},
#  {'k_type': 'Enter', 'timestamp': 1823.813, 'response_size': 304, 'seq': 2854}]

# %%
def plot_ssh_data(sequence):
    plt.figure(figsize=(12, 8))
    normal_keys_x = []
    normal_keys_y = []
    backspace_keys_x = []
    backspace_keys_y = []
    enter_keys_x = []
    enter_keys_y = []

    for keystroke_idx, keystroke in enumerate(sequence):
        if keystroke['k_type'] == 'Delete':
            backspace_keys_x.append(keystroke_idx)
            backspace_keys_y.append(keystroke['timestamp'])
        elif keystroke['k_type'] == 'Enter':
            enter_keys_x.append(keystroke_idx)
            enter_keys_y.append(keystroke['timestamp'])
        normal_keys_x.append(keystroke_idx)
        normal_keys_y.append(keystroke['timestamp'])
                
    # Plot normal keystrokes
    plt.plot(normal_keys_x, normal_keys_y, marker='o', linestyle='-', label=f'Session 1 Keystrokes', zorder=1)
    # Plot Backspace keystrokes
    plt.scatter(backspace_keys_x, backspace_keys_y, color='red', marker='x', label=f'Session 1 Backspaces', zorder=2)
    plt.scatter(enter_keys_x, enter_keys_y, color='green', marker='x', label=f'Session 1 Return', zorder=3)

    plt.title(f'Latencies for SSH sequence')
    plt.xlabel('Keystroke Sequence Number')
    plt.ylabel('Latency (ms)')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.grid(True)
    plt.show()

# %%
plot_ssh_data(ssh_data[4])

# %%
def plot_ssh_data(ssh_sessions):
    plt.figure(figsize=(12, 8))
    
    for sequence_idx, sequence in enumerate(ssh_sessions):
        keystroke_times = [event['timestamp'] for event in sequence if event['k_type'] == 'Keystroke']  # Convert to milliseconds
        enter_times = [event['timestamp'] for event in sequence if event['k_type'] == 'Enter']
        enter_sizes = [event['response_size'] for event in sequence if event['k_type'] == 'Enter']
        
        # Plotting keystrokes
        plt.plot(keystroke_times, [sequence_idx + 1] * len(keystroke_times), 'bo', label='Keystrokes' if sequence_idx == 0 else "")
        
        # Plotting Enter presses
        for enter_time, size in zip(enter_times, enter_sizes):
            plt.plot(enter_time, sequence_idx + 1, 'rx', label='Enter Press' if sequence_idx == 0 else "")
            plt.text(enter_time, sequence_idx + 1, f' {size}B', verticalalignment='bottom')

    plt.yticks(range(1, len(ssh_sessions) + 1), [f'Sequence {i+1}' for i in range(len(ssh_sessions))])
    plt.title('SSH Packet Timestamps and Enter Presses')
    plt.xlabel('Time (ms)')
    plt.ylabel('Sequence Number')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
plot_ssh_data(ssh_data)

# %%
## Dynamic Time Warping (DTW)

# %%
from dtaidistance import dtw
import numpy as np

# %%
ssh_data = convert_latencies(load_ssh_data("./sshniff_output/keystrokes.json"))
cmds = get_prepared_data(True)
cmds = handle_backspaces(cmds)
cmds = combine_common_tokens(cmds)

# %%
# Remove RETURN from intercept?
for sequence in ssh_data:
    sequence.pop()

# %%
# Expects get_mean_latencies('id', cmds['id'])
# Ignores RET, unless command has an extra character at the end.
def get_mean_latencies(command, command_dataset):
    means = [0 for i in range(len(command))]
    for letter_index, letter in enumerate(command):
        for sequence in command_dataset:
            means[letter_index] += sequence[letter_index]['latency']
    means = [i / len(command_dataset) for i in means]
    return np.array(means)

# %%
command = "iptables -L"
unlabeled_latencies = np.array([keystroke['timestamp'] for keystroke in ssh_data[4]])
cmd_mean_latencies = get_mean_latencies(command, cmds[command])

# %%
[keystroke['timestamp'] for keystroke in ssh_data[2]]
# Out:
# [0.0,
#  79.973,
#  151.947,
#  167.776,
#  184.25,
#  144.38,
#  87.696,
#  128.233,
#  79.999,
#  104.02,
#  191.915,
#  79.751,
#  79.902,
#  135.933,
#  48.148]

# %%
cmd_mean_latencies
# Out:
# array([  0.        , 172.18181818,  62.45454545,  72.72727273,
#        154.36363636,  80.18181818, 139.09090909,  87.18181818,
#        106.81818182,  87.18181818, 232.45454545])

# %%
unlabeled_norm = unlabeled_latencies / np.max(unlabeled_latencies)
known_norm = cmd_mean_latencies / np.max(cmd_mean_latencies)
distance = dtw.distance(unlabeled_norm, known_norm)
print("DTW Distance:", distance)
# Out:
# DTW Distance: 0.24139264595530577

# %%
def eliminate_candidates(intercept_length, command_dataset):
    """
    Reduces the scope of possible commands.

    Using the intercepted command's length, we can exclude commands with 
    a minimum length longer than the intercept. 
        i.e.: A five-letter intercept (XXXXX) cannot be ifconfig, no matter
        how well the signature might match.
    """
    candidates = {}
    for command in command_dataset.keys():
        splices = command.split(' ')
#        if splices[0] == 'sudo':
#            if len(splices[1]) + 5 > intercept_length:
#                # Ignore command if itself 
#                continue
        if len(splices[0]) > intercept_length:
            # Ignore command if it is longer than the intercepted length.
            # i.e., a five-letter intercept cannot be <ifconfig>, no matter how well it matches.
            continue
        else:
            candidates[command] = command_dataset[command]
    return candidates

# %%
def find_best_match(intercepted, command_dataset):
    """
    Creates an ordered list of the distance of all possible commands to an intercepted sequence.

    Distance is calculated using Dynamic Time Warping (DTW). 
    """
    unlabeled_latencies = np.array([keystroke['timestamp'] for keystroke in intercepted])
    unlabeled_norm = unlabeled_latencies / np.max(unlabeled_latencies)

    distances = []
    candidates = eliminate_candidates(len(intercepted), command_dataset)
    for command in candidates.keys():
        try:
            cmd_mean_latencies = get_mean_latencies(command, command_dataset[command])
        except:
            print(f"failed at {command}")
            continue
        known_norm = cmd_mean_latencies / np.max(cmd_mean_latencies)
        distance = dtw.distance(unlabeled_norm, known_norm)
        distances.append((command, distance))

    distances = sorted(distances, key=lambda x: x[1])
    return distances

# %%
find_best_match(ssh_data[3], cmds)
# Out:
# [('sudo apt upgrade ', 0.57410781494813),
#  ('ping -c 1 9.9.9.9', 0.638267611745968),
#  ('ifconfig', 0.7307000728774575),
#  ('cat /etc/hosts', 0.7403838809952429),
#  ('curl http://', 0.7795780237676415),
#  ('iptables -L', 0.7817823847563101),
#  ('tar --help', 0.7880689214823248),
#  ('cat /etc/resolv.conf', 0.7936981502072052),
#  ('systemctl', 0.8043030471932169),
#  ('systemctl stop ', 0.8079253702170153),
#  ('systemctl status ', 0.8267712297400878),
#  ('touch ', 0.8480534614210572),
#  ('cat /etc/passwd', 0.8500276724142628),
#  ('iptables -S', 0.865134638281377),
#  ('wget https://', 0.8664987368072451),
#  ('sudo apt update', 0.8701679313553401),
#  ('df -hT /', 0.8703338084395944),
#  ('rm -rf /tmp/*', 0.8782204900943745),
#  ('systemctl restart ', 0.892205146199822),
#  ('tail /var/log/syslog', 0.9050254308315562),
#  ('systemctl start ', 0.9176605670821919),
#  ('mv * ../', 0.9345266490351055),
#  ('uptime', 0.9997655825972209),
#  ('exit', 1.0078100550645708),
#  ('whoami', 1.0350429240855592),
#  ('sudo su', 1.0393941649390668),
#  ('sudo', 1.05509660613702),
#  ('cd', 1.734480025920953),
#  ('id', 1.9712811751442183)]

# %%
sudo = ssh_data[2][:5]

# %%
find_best_match(sudo, cmds)
# Out:
# [('sudo', 0.3477635275587289),
#  ('rm -rf /tmp/*', 0.3769109701734561),
#  ('cd', 0.37794177956394887),
#  ('tar --help', 0.3988128583661368),
#  ('touch ', 0.43567575781429924),
#  ('id', 0.4765795309550633),
#  ('sudo su', 0.5266152825897691),
#  ('curl http://', 0.5623426298853395),
#  ('exit', 0.6313450587666717),
#  ('wget https://', 0.6593016162287152),
#  ('df -hT /', 0.6899212801101497),
#  ('cat /etc/hosts', 0.8358267923331405),
#  ('ping -c 1 9.9.9.9', 0.8565467769263311),
#  ('tail /var/log/syslog', 0.9465034088496813),
#  ('sudo apt upgrade ', 0.9608209146707403),
#  ('sudo apt update', 0.980940692820885),
#  ('mv * ../', 1.0045429304023148),
#  ('cat /etc/passwd', 1.2376833046910585),
#  ('cat /etc/resolv.conf', 1.2481967669622207)]

# %%
# HMM Stuff

# %%
with open("./commands.json", "r") as f:
    commands = json.load(f)

# %%
s_cmds = []
for category in commands['commands']:
    s_cmds.extend(category['patterns'])
s_cmds.extend(commands['commonFlags'])
s_cmds.extend(commands['commonPathStarts'])

# %%
s_cmds
# Out:
# ['ls -l',
#  'cd',
#  'pwd',
#  'touch ',
#  'cp file1 file2',
#  'mv file1 file2',
#  'rm file',
#  'mkdir directory',
#  'rmdir directory',
#  'cat file',
#  'less file',
#  'nano file',
#  'vim file',
#  'chmod +x file',
#  'chown user:group file',
#  'sudo command',
#  'su - user',
#  'whoami',
#  'man command',
#  "echo 'text'",
#  'head ',
#  'tail -f ',
#  'exit',
#  'ps -aux',
#  'top',
#  'htop',
#  'kill pid',
#  'df -h',
#  'du -h directory',
#  'uname -a',
#  'uptime',
#  'free -m',
#  'vmstat',
#  'iostat',
#  'systemctl status service',
#  'service name start',
#  'ping host',
#  'netstat -tuln',
#  'ss -tuln',
#  'curl https://example.com',
#  'wget https://example.com',
#  'scp file user@host:path',
#  'ssh user@host',
#  'iptables -L',
#  'ufw enable',
#  'ip addr',
#  'apt-get update',
#  'apt-get install package',
#  'dpkg -i package.deb',
#  'yum install package',
#  'dnf install package',
#  'pacman -Syu',
#  'pacman -S package',
#  "grep -i 'pattern' file",
#  "awk '/pattern/ {action}' file",
#  "sed 's/find/replace/' file",
#  'sort file',
#  'uniq file',
#  'tar -czvf archive.tar.gz directory',
#  'gzip file',
#  'unzip archive.zip',
#  'zip archive.zip file',
#  'dd if=/dev/zero of=file bs=1M count=10',
#  'python3 script.py',
#  'pip3 install package',
#  '--help',
#  '-v',
#  '--version',
#  './',
#  '../',
#  '/']

# %%
char_pairs = set()

for cmd in s_cmds:
    for i in range(len(cmd) - 1):
        pair = cmd[i:i+2]
        char_pairs.add(pair)

# %%
char_pairs
# Out:
# {" '",
#  ' +',
#  ' -',
#  ' a',
#  ' b',
#  ' c',
#  ' d',
#  ' e',
#  ' f',
#  ' h',
#  ' i',
#  ' n',
#  ' o',
#  ' p',
#  ' s',
#  ' u',
#  ' {',
#  "' ",
#  "'/",
#  "'p",
#  "'s",
#  "'t",
#  '+x',
#  '- ',
#  '--',
#  '-L',
#  '-S',
#  '-a',
#  '-c',
#  '-f',
#  '-g',
#  '-h',
#  '-i',
#  '-l',
#  '-m',
#  '-t',
#  '-v',
#  '..',
#  './',
#  '.c',
#  '.d',
#  '.g',
#  '.p',
#  '.t',
#  '.z',
#  '/ ',
#  "/'",
#  '//',
#  '/d',
#  '/e',
#  '/f',
#  '/p',
#  '/r',
#  '/z',
#  '1 ',
#  '10',
#  '1M',
#  '3 ',
#  ':/',
#  ':g',
#  ':p',
#  '=/',
#  '=1',
#  '=f',
#  '@h',
#  'M ',
#  'S ',
#  'Sy',
#  'ab',
#  'ac',
#  'ad',
#  'ag',
#  'ai',
#  'al',
#  'am',
#  'an',
#  'ap',
#  'ar',
#  'at',
#  'au',
#  'aw',
#  'bl',
#  'bs',
#  'ca',
#  'cd',
#  'ce',
#  'ch',
#  'ck',
#  'cm',
#  'co',
#  'cp',
#  'cr',
#  'ct',
#  'cu',
#  'cz',
#  'd ',
#  'd/',
#  'da',
#  'dd',
#  'de',
#  'df',
#  'di',
#  'dn',
#  'do',
#  'dp',
#  'dr',
#  'du',
#  'e ',
#  'e.',
#  'e/',
#  'e1',
#  'e2',
#  'ea',
#  'eb',
#  'ec',
#  'ed',
#  'ee',
#  'el',
#  'em',
#  'en',
#  'ep',
#  'er',
#  'es',
#  'et',
#  'ev',
#  'ex',
#  'f ',
#  'f=',
#  'fi',
#  'fr',
#  'fw',
#  'g ',
#  'ge',
#  'gr',
#  'gz',
#  'h ',
#  'he',
#  'hi',
#  'hm',
#  'ho',
#  'ht',
#  'i ',
#  'ic',
#  'id',
#  'if',
#  'il',
#  'im',
#  'in',
#  'io',
#  'ip',
#  'iq',
#  'ir',
#  'it',
#  'iv',
#  'k ',
#  'ka',
#  'kd',
#  'kg',
#  'ki',
#  'l ',
#  'la',
#  'le',
#  'll',
#  'ln',
#  'lp',
#  'ls',
#  'm ',
#  'ma',
#  'mc',
#  'md',
#  'me',
#  'mi',
#  'mk',
#  'mm',
#  'mo',
#  'mp',
#  'ms',
#  'mv',
#  'n ',
#  "n'",
#  'n/',
#  'n3',
#  'na',
#  'nd',
#  'ne',
#  'nf',
#  'ng',
#  'ni',
#  'no',
#  'ns',
#  'nt',
#  'nz',
#  'n}',
#  'o ',
#  'oa',
#  'od',
#  'of',
#  'om',
#  'on',
#  'op',
#  'or',
#  'os',
#  'ou',
#  'ow',
#  'p ',
#  'p3',
#  'pa',
#  'pd',
#  'pi',
#  'pk',
#  'pl',
#  'ps',
#  'pt',
#  'pw',
#  'py',
#  'q ',
#  'r ',
#  'r.',
#  'r:',
#  'r@',
#  'rc',
#  're',
#  'ri',
#  'rl',
#  'rm',
#  'rn',
#  'ro',
#  'rs',
#  'rt',
#  'rv',
#  'ry',
#  's ',
#  's/',
#  's:',
#  's=',
#  'sc',
#  'se',
#  'sh',
#  'si',
#  'so',
#  'ss',
#  'st',
#  'su',
#  'sy',
#  't ',
#  "t'",
#  't-',
#  't.',
#  't:',
#  't=',
#  'ta',
#  'te',
#  'th',
#  'ti',
#  'tl',
#  'to',
#  'tp',
#  'ts',
#  'tt',
#  'tu',
#  'u ',
#  'uc',
#  'ud',
#  'uf',
#  'ul',
#  'um',
#  'un',
#  'up',
#  'ur',
#  'us',
#  'ux',
#  'v ',
#  'v/',
#  've',
#  'vf',
#  'vi',
#  'vm',
#  'w ',
#  'wd',
#  'wg',
#  'wh',
#  'wk',
#  'wn',
#  'x ',
#  'xa',
#  'xi',
#  'xt',
#  'ys',
#  'yt',
#  'yu',
#  'z ',
#  'ze',
#  'zi',
#  'zv',
#  '{a',
#  "}'"}

# %%
len(char_pairs)
# Out:
# 296

# %%
def get_minlen(command: str) -> int:
    # How do we reliably determine minimum length?
    # Split at first ' ' doesn't cover cmds like 'cp src dst' but it is a start.
    splice = command.split(" ", 1)[0]
    return len(splice)

# %%
def get_charpairs(command: str) -> (str, set()):
    if len(command) < 2:
        return
    first = set([command[:2]])
    rest = set()
    for i in range(1, len(command)-1):
        rest.add(command[i:i+2])
    return [first, rest]

# %%
# This one doesn't make much sense. Each start state can only logically produce certain following states, so it doesn't make sense to pool them by length
def make_state_objects(commands: list):
    # minlen -> (startstates, states)?
    state_objects = {}
    # (minlen, startstate, states)
    for command in commands:
        minlen = get_minlen(command)
        pairs = get_charpairs(command)
        if not pairs:
            continue
        if minlen in state_objects:
            state_objects[minlen][0] = state_objects[minlen][0].union(pairs[0])
            state_objects[minlen][1] = state_objects[minlen][1].union(pairs[1])
        else:
            state_objects[minlen] = pairs
    return state_objects

# %%
def get_pairs(command: str):
    pairs = []
    for i in range(len(command) - 1):
        pair = command[i:i+2]
        pairs.append(pair)
    return pairs

# %%
def make_len_map(commands: list):
    # minlen -> [["if", "fc", "co", "on", "nf", "fi", "ig"], ...]
    lenmap = {}
    for command in commands:
        minlen = get_minlen(command)
        pairs = get_pairs(command)
        if not pairs:
            continue
        if minlen in lenmap:
            lenmap[minlen].append(pairs)
        else:
            lenmap[minlen] = [pairs]
    return lenmap

# %%
mp = make_len_map(s_cmds)

# %%
mp[5]
# Out:
# [['to', 'ou', 'uc', 'ch', 'h '],
#  ['mk',
#   'kd',
#   'di',
#   'ir',
#   'r ',
#   ' d',
#   'di',
#   'ir',
#   're',
#   'ec',
#   'ct',
#   'to',
#   'or',
#   'ry'],
#  ['rm',
#   'md',
#   'di',
#   'ir',
#   'r ',
#   ' d',
#   'di',
#   'ir',
#   're',
#   'ec',
#   'ct',
#   'to',
#   'or',
#   'ry'],
#  ['ch', 'hm', 'mo', 'od', 'd ', ' +', '+x', 'x ', ' f', 'fi', 'il', 'le'],
#  ['ch',
#   'ho',
#   'ow',
#   'wn',
#   'n ',
#   ' u',
#   'us',
#   'se',
#   'er',
#   'r:',
#   ':g',
#   'gr',
#   'ro',
#   'ou',
#   'up',
#   'p ',
#   ' f',
#   'fi',
#   'il',
#   'le'],
#  ['un', 'na', 'am', 'me', 'e ', ' -', '-a'],
#  ['un',
#   'nz',
#   'zi',
#   'ip',
#   'p ',
#   ' a',
#   'ar',
#   'rc',
#   'ch',
#   'hi',
#   'iv',
#   've',
#   'e.',
#   '.z',
#   'zi',
#   'ip']]
